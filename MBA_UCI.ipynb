# %%
# !pip install mlxtend
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.4 MB 2.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.4 MB 3.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt

# %%
mba_data = pd.read_excel("Online Retail.xlsx")

# %%
mba_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
mba_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
mba_data.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
mba_data.dropna(inplace=True)

# %%
len(mba_data)
# Out:
# 406829

# %%
mba_data['InvoiceNo'] = mba_data['InvoiceNo'].astype('str')
mba_data = mba_data[~mba_data['InvoiceNo'].str.contains('C')]

# %%
len(mba_data)
# Out:
# 397924

# %%
top10_countries = mba_data['Country'].value_counts().head(10)
top10_countries
# Out:
# Country
# United Kingdom    354345
# Germany             9042
# France              8342
# EIRE                7238
# Spain               2485
# Netherlands         2363
# Belgium             2031
# Switzerland         1842
# Portugal            1462
# Australia           1185
# Name: count, dtype: int64

# %%
plt.figure(figsize=[10,10])
plt.pie(top10_countries, labels=top10_countries.index, autopct='%0.0f%%', labeldistance=1.3)
plt.title("Transaction distribution by country")
plt.show()

# %% [markdown]
# ## Group by Invoice No and Description to show the quantity of each item purchased in each transaction

# %%
basket = mba_data[mba_data['Country']=='United Kingdom']\
         .groupby(['InvoiceNo', 'Description'])['Quantity']\
         .sum().unstack().reset_index().fillna(0)\
         .set_index('InvoiceNo')

# %%
basket
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
# ...                                     ...                             ...
# 581582                                  0.0                             0.0
# 581583                                  0.0                             0.0
# 581584                                  0.0                             0.0
# 581585                                  0.0                             0.0
# 581586                                  0.0                             0.0
#
# ...

# %% [markdown]
# ## One Hot Encode

# %%
def val_encode(x):
    if x<= 0:
        return 0
    if x>=1:
        return 1

# %%
basket_enc = basket.map(val_encode)

# %%
basket_enc
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# 581582                                    0                               0
# 581583                                    0                               0
# 581584                                    0                               0
# 581585                                    0                               0
# 581586                                    0                               0
#
# ...

# %%
basket_filt = basket_enc[(basket_enc>0).sum(axis=1) >= 2]

# %% [markdown]
# ## Apply Apriori Algorithm

# %%
frequent_itemset = apriori(basket_filt, min_support=0.03, use_colnames=True)

# %%
frequent_itemset = frequent_itemset.sort_values('support', ascending=False)

# %%
frequent_itemset
# Out:
#       support                                           itemsets
# 99   0.121358               (WHITE HANGING HEART T-LIGHT HOLDER)
# 44   0.093197                          (JUMBO BAG RED RETROSPOT)
# 80   0.090466                         (REGENCY CAKESTAND 3 TIER)
# 6    0.084417                    (ASSORTED COLOUR BIRD ORNAMENT)
# 71   0.082986                                    (PARTY BUNTING)
# ..        ...                                                ...
# 18   0.030697                               (DOORMAT UNION FLAG)
# 107  0.030632  (LUNCH BAG PINK POLKADOT, LUNCH BAG RED RETROS...
# 87   0.030502                    (SET OF 3 HEART COOKIE CUTTERS)
# 14   0.030372                             (DOLLY GIRL LUNCH BOX)
# 25   0.030047                                (GUMBALL COAT RACK)
#
# [108 rows x 2 columns]

# %% [markdown]
# ## Apply Association Rules

# %%
assoc_rules = association_rules(frequent_itemset, metric='lift', min_threshold=1).sort_values('lift', ascending=False).reset_index(drop=True)

# %%
assoc_rules
# Out:
#                           antecedents                         consequents  \
# 0  (ROSES REGENCY TEACUP AND SAUCER )   (GREEN REGENCY TEACUP AND SAUCER)
# 1   (GREEN REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER )
# 2           (LUNCH BAG RED RETROSPOT)           (LUNCH BAG PINK POLKADOT)
# 3           (LUNCH BAG PINK POLKADOT)           (LUNCH BAG RED RETROSPOT)
# 4           (JUMBO BAG RED RETROSPOT)           (JUMBO BAG PINK POLKADOT)
# 5           (JUMBO BAG PINK POLKADOT)           (JUMBO BAG RED RETROSPOT)
# 6           (LUNCH BAG  BLACK SKULL.)           (LUNCH BAG RED RETROSPOT)
# 7           (LUNCH BAG RED RETROSPOT)           (LUNCH BAG  BLACK SKULL.)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.043900            0.039802  0.030957    0.705185  17.717202
# 1            0.039802            0.043900  0.030957    0.777778  17.717202
# 2            0.072841            0.055086  0.030632    0.420536   7.634188
# ...
